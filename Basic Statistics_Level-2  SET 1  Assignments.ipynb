# %% [markdown]
# # Look at the data given below. Plot the data, find the outliers and find the outliers and find out μ,σ,σ^2
#
# 1.Name of company Measure X Allied Signal 24.23% Bankers Trust 25.53% General Mills 25.41% ITT Industries 24.14% J.P.Morgan & Co. 29.62% Lehman Brothers 28.25% Marriott 25.81% MCI 24.39% Merrill Lynch 40.26% Microsoft 32.95% Morgan Stanley 91.36% Sun Microsystems 25.99% Travelers 39.42% US Airways 26.71% Warner-Lambert 35.00%

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as smf
import warnings
warnings.filterwarnings('ignore')

# %%
x=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
name=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers',
      'Marriott','MCI','Merrill Lynch','Microsoft','Morgan Stanley','Sun Microsystems','Travelers','US Airways',
      'Warner-Lambert']

# %%
# Pie Plot
plt.figure(figsize=(10,15))
plt.pie(x,labels=name,autopct='%1.0f%%')
plt.show()

# %%
# finding outliers using boxplot
sns.boxplot(x)
# Out:
# C:\Users\PCW\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
#calculatting mean
x.mean()
# Out:
# 33.27133333333333

# %%
#calculatting std
x.std()
# Out:
# 16.945400921222028

# %%
#calculatting var
x.var()
# Out:
# 287.1466123809524

# %%
x.max()
# Out:
# 91.36
